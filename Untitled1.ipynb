# %%
	# load dataset
	from pycaret.datasets import get_data
	diabetes = get_data('iris')
# Out:
#    sepal_length  sepal_width  petal_length  petal_width      species
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %%
	from pycaret.classification import *
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 from pycaret.classification import *
#
# File /opt/miniconda3/envs/pycaret/lib/python3.8/site-packages/pycaret/classification/__init__.py:1
# ----> 1 from pycaret.classification.functional import (
#       2     add_metric,
#       3     automl,
#       4     blend_models,
#       5     calibrate_model,
#       6     check_drift,
#       7     check_fairness,
#       8     compare_models,
#       9     convert_model,
#      10     create_api,
#      11     create_app,
#      12     create_docker,
#      13     create_model,
#      14     dashboard,
#      15     deploy_model,
#      16     ensemble_model,
#      17     evaluate_model,
#      18     finalize_model,
#      19     get_allowed_engines,
#      20     get_config,
#      21     get_current_experiment,
#      22     get_engine,
#      23     get_leaderboard,
#      24     get_logs,
#      25     get_metrics,
#      26     interpret_model,
#      27     load_experiment,
#      28     load_model,
#      29     models,
#      30     optimize_threshold,
#      31     plot_model,
#      32     predict_model,
#      33     pull,
#      34     remove_metric,
#      35     save_experiment,
#      36     save_model,
#      37     set_config,
#      38     set_current_experiment,
#      39     setup,
#      40     stack_models,
#      41     tune_model,
#      42 )
#      43 from pycaret.classification.oop import ClassificationExperiment
#      45 __all__ = [
#      46     "ClassificationExperiment",
#      47     "setup",
#    (...)
#      86     "check_drift",
#      87 ]
#
# File /opt/miniconda3/envs/pycaret/lib/python3.8/site-packages/pycaret/classification/functional.py:8
#       5 import pandas as pd
#       6 from joblib.memory import Memory
# ----> 8 from pycaret.classification.oop import ClassificationExperiment
#       9 from pycaret.internal.parallel.parallel_backend import ParallelBackend
#      10 from pycaret.loggers.base_logger import BaseLogger
#
# File /opt/miniconda3/envs/pycaret/lib/python3.8/site-packages/pycaret/classification/oop.py:31
#      29 from pycaret.internal.pipeline import Pipeline as InternalPipeline
#      30 from pycaret.internal.preprocess.preprocessor import Preprocessor
# ---> 31 from pycaret.internal.pycaret_experiment.non_ts_supervised_experiment import (
#      32     _NonTSSupervisedExperiment,
#      33 )
#      34 from pycaret.internal.validation import is_sklearn_cv_generator
#      35 from pycaret.loggers.base_logger import BaseLogger
#
# File /opt/miniconda3/envs/pycaret/lib/python3.8/site-packages/pycaret/internal/pycaret_experiment/non_ts_supervised_experiment.py:3
#       1 import pandas as pd
# ----> 3 from pycaret.internal.pycaret_experiment.supervised_experiment import (
#       4     _SupervisedExperiment,
#       5 )
#       8 class _NonTSSupervisedExperiment(_SupervisedExperiment):
#       9     def __init__(self) -> None:
#
# File /opt/miniconda3/envs/pycaret/lib/python3.8/site-packages/pycaret/internal/pycaret_experiment/supervised_experiment.py:57
#      50 from pycaret.internal.patches.sklearn import fit_and_score as fs
#      51 from pycaret.internal.pipeline import (
#      52     Pipeline,
#      53     estimator_pipeline,
#      54     get_pipeline_estimator_label,
#      55     get_pipeline_fit_kwargs,
#      56 )
# ---> 57 from pycaret.internal.pycaret_experiment.tabular_experiment import _TabularExperiment
#      58 from pycaret.internal.tunable import TunableMixin
#      59 from pycaret.internal.validation import is_fitted, is_sklearn_cv_generator
#
# File /opt/miniconda3/envs/pycaret/lib/python3.8/site-packages/pycaret/internal/pycaret_experiment/tabular_experiment.py:29
#      27 from pycaret.internal.display import CommonDisplay
#      28 from pycaret.internal.logging import create_logger, get_logger, redirect_output
# ---> 29 from pycaret.internal.memory import get_memory
#      30 from pycaret.internal.pipeline import Pipeline as InternalPipeline
#      31 from pycaret.internal.plots.helper import MatplotlibDefaultDPI
#
# File /opt/miniconda3/envs/pycaret/lib/python3.8/site-packages/pycaret/internal/memory.py:25
#      22 from typing import TYPE_CHECKING, Union
#      24 from joblib.hashing import Hasher, Pickler
# ---> 25 from joblib.memory import (
#      26     MemorizedFunc,
#      27     MemorizedResult,
#      28     Memory,
#      29     NotMemorizedResult,
#      30     _format_load_msg,
#      31     filter_args,
#      32     format_call,
#      33     format_signature,
#      34     format_time,
#      35     get_func_name,
#      36 )
#      37 from xxhash import xxh128 as xxh
#      39 try:
#
# ImportError: cannot import name '_format_load_msg' from 'joblib.memory' (/opt/miniconda3/envs/pycaret/lib/python3.8/site-packages/joblib/memory.py)

# %%
	# load dataset
	from pycaret.datasets import get_data
	diabetes = get_data('iris')
# Out:
#    sepal_length  sepal_width  petal_length  petal_width      species
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %%
	from pycaret.classification import *
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 from pycaret.classification import *
#
# File /opt/miniconda3/envs/pycaret/lib/python3.8/site-packages/pycaret/classification/__init__.py:1
# ----> 1 from pycaret.classification.functional import (
#       2     add_metric,
#       3     automl,
#       4     blend_models,
#       5     calibrate_model,
#       6     check_drift,
#       7     check_fairness,
#       8     compare_models,
#       9     convert_model,
#      10     create_api,
#      11     create_app,
#      12     create_docker,
#      13     create_model,
#      14     dashboard,
#      15     deploy_model,
#      16     ensemble_model,
#      17     evaluate_model,
#      18     finalize_model,
#      19     get_allowed_engines,
#      20     get_config,
#      21     get_current_experiment,
#      22     get_engine,
#      23     get_leaderboard,
#      24     get_logs,
#      25     get_metrics,
#      26     interpret_model,
#      27     load_experiment,
#      28     load_model,
#      29     models,
#      30     optimize_threshold,
#      31     plot_model,
#      32     predict_model,
#      33     pull,
#      34     remove_metric,
#      35     save_experiment,
#      36     save_model,
#      37     set_config,
#      38     set_current_experiment,
#      39     setup,
#      40     stack_models,
#      41     tune_model,
#      42 )
#      43 from pycaret.classification.oop import ClassificationExperiment
#      45 __all__ = [
#      46     "ClassificationExperiment",
#      47     "setup",
#    (...)
#      86     "check_drift",
#      87 ]
#
# File /opt/miniconda3/envs/pycaret/lib/python3.8/site-packages/pycaret/classification/functional.py:8
#       5 import pandas as pd
#       6 from joblib.memory import Memory
# ----> 8 from pycaret.classification.oop import ClassificationExperiment
#       9 from pycaret.internal.parallel.parallel_backend import ParallelBackend
#      10 from pycaret.loggers.base_logger import BaseLogger
#
# File /opt/miniconda3/envs/pycaret/lib/python3.8/site-packages/pycaret/classification/oop.py:31
#      29 from pycaret.internal.pipeline import Pipeline as InternalPipeline
#      30 from pycaret.internal.preprocess.preprocessor import Preprocessor
# ---> 31 from pycaret.internal.pycaret_experiment.non_ts_supervised_experiment import (
#      32     _NonTSSupervisedExperiment,
#      33 )
#      34 from pycaret.internal.validation import is_sklearn_cv_generator
#      35 from pycaret.loggers.base_logger import BaseLogger
#
# File /opt/miniconda3/envs/pycaret/lib/python3.8/site-packages/pycaret/internal/pycaret_experiment/non_ts_supervised_experiment.py:3
#       1 import pandas as pd
# ----> 3 from pycaret.internal.pycaret_experiment.supervised_experiment import (
#       4     _SupervisedExperiment,
#       5 )
#       8 class _NonTSSupervisedExperiment(_SupervisedExperiment):
#       9     def __init__(self) -> None:
#
# File /opt/miniconda3/envs/pycaret/lib/python3.8/site-packages/pycaret/internal/pycaret_experiment/supervised_experiment.py:57
#      50 from pycaret.internal.patches.sklearn import fit_and_score as fs
#      51 from pycaret.internal.pipeline import (
#      52     Pipeline,
#      53     estimator_pipeline,
#      54     get_pipeline_estimator_label,
#      55     get_pipeline_fit_kwargs,
#      56 )
# ---> 57 from pycaret.internal.pycaret_experiment.tabular_experiment import _TabularExperiment
#      58 from pycaret.internal.tunable import TunableMixin
#      59 from pycaret.internal.validation import is_fitted, is_sklearn_cv_generator
#
# File /opt/miniconda3/envs/pycaret/lib/python3.8/site-packages/pycaret/internal/pycaret_experiment/tabular_experiment.py:29
#      27 from pycaret.internal.display import CommonDisplay
#      28 from pycaret.internal.logging import create_logger, get_logger, redirect_output
# ---> 29 from pycaret.internal.memory import get_memory
#      30 from pycaret.internal.pipeline import Pipeline as InternalPipeline
#      31 from pycaret.internal.plots.helper import MatplotlibDefaultDPI
#
# File /opt/miniconda3/envs/pycaret/lib/python3.8/site-packages/pycaret/internal/memory.py:25
#      22 from typing import TYPE_CHECKING, Union
#      24 from joblib.hashing import Hasher, Pickler
# ---> 25 from joblib.memory import (
#      26     MemorizedFunc,
#      27     MemorizedResult,
#      28     Memory,
#      29     NotMemorizedResult,
#      30     _format_load_msg,
#      31     filter_args,
#      32     format_call,
#      33     format_signature,
#      34     format_time,
#      35     get_func_name,
#      36 )
#      37 from xxhash import xxh128 as xxh
#      39 try:
#
# ImportError: cannot import name '_format_load_msg' from 'joblib.memory' (/opt/miniconda3/envs/pycaret/lib/python3.8/site-packages/joblib/memory.py)
